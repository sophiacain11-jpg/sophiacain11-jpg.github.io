# %% [markdown]
# # Project 1

# %% [markdown]
# I will be working with data NYC Open Data to visualize data on the leading causes of death in New York City.
#
# More information on this data can be found at the link below:
#
# https://data.cityofnewyork.us/Health/New-York-City-Leading-Causes-of-Death/jb7j-dtam/data_preview

# %% [markdown]
# ### Import, Clean, and Read Data

# %%
import pandas as pd

df_NYC = pd.read_csv("NYC_Leading_Causes_of_Death.csv")

df_women_2021_deaths = df_NYC[(df_NYC["Sex"] == "Female") & (df_NYC["Year"] == 2021)]

df_women_2021_deaths
# Out:
#      Year                                      Leading Cause     Sex  \
# 1    2021                          Alzheimer's Disease (G30)  Female
# 2    2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 11   2021          Cerebrovascular Disease (Stroke: I60-I69)  Female
# 14   2021              Malignant Neoplasms (Cancer: C00-C97)  Female
# 17   2021                                   All Other Causes  Female
# ..    ...                                                ...     ...
# 128  2021  Mental and Behavioral Disorders due to Acciden...  Female
# 129  2021                                   All Other Causes  Female
# 130  2021     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 134  2021                                           Covid-19  Female
# 135  2021              Malignant Neoplasms (Cancer: C00-C97)  Female
#
#             Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 1       Not Stated/Unknown      7        NaN                     NaN
# 2       Not Stated/Unknown    113        NaN                     NaN
# 11      Not Stated/Unknown     17        NaN                     NaN
# 14      Non-Hispanic Black   1621      161.9                   118.6
# 17   Other Race/ Ethnicity     71        NaN                     NaN
# ..                     ...    ...        ...                     ...
# 128     Non-Hispanic White    189       13.8                    13.1
# 129     Non-Hispanic White   2670      195.4                   116.8
# 130     Non-Hispanic Black   2356      235.4                   162.7
# 134     Not Stated/Unknown     33        NaN                     NaN
# 135     Not Stated/Unknown     59        NaN                     NaN
#
# [69 rows x 7 columns]

# %% [markdown]
# ### Compute Mean, Median, and Mode with Pandas

# %%
import pandas as pd

# make of copy of data fram
df_women_2021_deaths = df_NYC[
    (df_NYC["Sex"] == "Female") & (df_NYC["Year"] == 2021)
].copy()

# clean 'Deaths' and 'Death Rate' columns and convert to numeric
df_women_2021_deaths["Deaths"] = pd.to_numeric(
    df_women_2021_deaths["Deaths"], errors="coerce"
)
df_women_2021_deaths["Death Rate"] = pd.to_numeric(
    df_women_2021_deaths["Death Rate"], errors="coerce"
)

# calculate and print mean
mean_value = df_women_2021_deaths[["Deaths", "Death Rate"]].mean()
print("Mean:\n", mean_value)

# calculate and print median
median_value = df_women_2021_deaths[["Deaths", "Death Rate"]].median()
print("\nMedian:\n", median_value)

# calculate and print mode
mode_value = df_women_2021_deaths[["Deaths", "Death Rate"]].mode().iloc[0]
print("\nMode:\n", mode_value)
# Out:
# Mean:
#  Deaths        443.637681
# Death Rate     60.422727
# dtype: float64
#
# Median:
#  Deaths        169.00
# Death Rate     23.95
# dtype: float64
#
# Mode:
#  Deaths        7.0
# Death Rate    6.0
# Name: 0, dtype: float64
